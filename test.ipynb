# %%
import torch
import torch.nn.functional as F
from torchinfo import summary
import warnings
warnings.filterwarnings("ignore")

# %%
from metnet import MetNet2
import torch
import torch.nn.functional as F

model = MetNet2(
        forecast_steps=24,
        input_size=128,
        input_channels=3,
        sat_channels=1,
        num_input_timesteps=12,
        upsampler_channels=64,
        lstm_channels=32,
        num_context_blocks=2,
        encoder_channels=64,
        upsampler_channel=128,
        lead_time_features=128,
        output_channels=1,
        )

# summary(model, (2, 12, 3, 128, 128))

# MetNet expects original HxW to be 4x the input size
x = torch.randn((2, 12, 3, 128, 128))
out = []
for lead_time in range(3):
        out.append(model(x, lead_time))
out = torch.stack(out, dim=1)
out.shape
# y = torch.rand((2,8,12,64,64))
# F.mse_loss(out, y).backward()
# Out:
# torch.Size([2, 3, 1, 128, 128])

# %%
summary(model, (2, 12, 3, 128, 128))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# MetNet2                                       --                        --
# ├─ConditionWithTimeMetNet2: 1                 --                        --
# │    └─ModuleList: 2-1                        --                        --
# ├─ConvLSTM: 1                                 --                        --
# │    └─ModuleList: 2-2                        --                        --
# ├─TimeDistributed: 1                          --                        --
# │    └─DownSampler: 2                         --                        --
# │    │    └─Sequential: 3-1                   --                        9,303
# ├─ModuleList: 1-1                             --                        --
# ├─ModuleList: 1-2                             --                        --
# ├─ModuleList: 1-3                             --                        --
# ├─TimeDistributed: 1-4                        [2, 12, 3, 32, 32]        --
# │    └─DownSampler: 2-3                       [24, 3, 32, 32]           --
# ├─ConditionWithTimeMetNet2: 1                 --                        --
# │    └─ModuleList: 2-4                        --                        (recursive)
# ├─ConvLSTM: 1                                 --                        --
# │    └─ModuleList: 2-5                        --                        (recursive)
# ├─ConditionWithTimeMetNet2: 1-5               [2, 24, 2]                --
# │    └─ModuleList: 2-1                        --                        --
# │    │    └─Linear: 3-2                       [2, 128]                  3,200
# │    │    └─Linear: 3-3                       [2, 48]                   6,192
# ├─ConvLSTM: 1-6                               [2, 12, 32, 32, 32]       --
# │    └─ModuleList: 2-2                        --                        --
# │    │    └─ConvLSTMCell: 3-4                 [2, 32, 32, 32]           40,448
# │    │    └─ConvLSTMCell: 3-5                 [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-6                 [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-7                 [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-8                 [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-9                 [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-10                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-11                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-12                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-13                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-14                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-15                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-16                [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-17                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-18                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-19                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-20                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-21                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-22                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-23                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-24                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-25                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-26                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-27                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-28                [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-29                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-30                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-31                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-32                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-33                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-34                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-35                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-36                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-37                [2, 32, 32, 32]           (recursive)
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-38                    --                        --
# ├─ModuleList: 1-7                             --                        (recursive)
# │    └─DilatedResidualConv: 2-6               --                        (recursive)
# │    │    └─Conv2d: 3-39                      --                        (recursive)
# ├─ConvLSTM: 1                                 --                        --
# │    └─ModuleList: 2-2                        --                        --
# │    │    └─ConvLSTMCell: 3-40                [2, 32, 32, 32]           (recursive)
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2-6               --                        (recursive)
# │    │    └─Conv2d: 3-41                      --                        (recursive)
# ├─ConvLSTM: 1                                 --                        --
# │    └─ModuleList: 2-2                        --                        --
# │    │    └─ConvLSTMCell: 3-42                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-43                [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-44                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-45                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-46                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-47                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-48                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-49                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-50                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-51                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-52                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-53                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-54                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-55                [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-56                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-57                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-58                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-59                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-60                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-61                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-62                [2, 32, 32, 32]           (recursive)
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-63                    --                        --
# ├─Upsample: 1-8                               --                        --
# ├─Conv2d: 1-9                                 --                        (recursive)
# ├─ModuleList: 1-10                            --                        (recursive)
# │    └─DilatedResidualConv: 2-7               --                        (recursive)
# │    │    └─Conv2d: 3-64                      --                        (recursive)
# ├─ConvLSTM: 1                                 --                        --
# │    └─ModuleList: 2-2                        --                        --
# │    │    └─ConvLSTMCell: 3-65                [2, 32, 32, 32]           (recursive)
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2-7               --                        (recursive)
# │    │    └─Conv2d: 3-66                      --                        (recursive)
# ├─ConvLSTM: 1                                 --                        --
# │    └─ModuleList: 2-2                        --                        --
# │    │    └─ConvLSTMCell: 3-67                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-68                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-69                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-70                [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-71                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-72                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-73                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-74                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-75                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-76                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-77                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-78                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-79                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-80                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-81                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-82                [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-83                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-84                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-85                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-86                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-87                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-88                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-89                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-90                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-91                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-92                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-93                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-94                [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-95                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-96                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-97                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-98                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-99                [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-100               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-101               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-102               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-103               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-104               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-105               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-106               [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-107               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-108               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-109               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-110               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-111               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-112               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-113               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-114               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-115               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-116               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-117               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-118               [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-119               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-120               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-121               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-122               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-123               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-124               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-125               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-126               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-127               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-128               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-129               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-130               [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-131               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-132               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-133               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-134               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-135               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-136               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-137               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-138               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-139               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-140               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-141               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-142               [2, 32, 32, 32]           73,856
# │    │    └─ConvLSTMCell: 3-143               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-144               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-145               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-146               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-147               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-148               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-149               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-150               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-151               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-152               [2, 32, 32, 32]           (recursive)
# │    │    └─ConvLSTMCell: 3-153               [2, 32, 32, 32]           (recursive)
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2-8               [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-154                     [2, 64, 32, 32]           18,496
# │    │    └─LeadTimeConditioner: 3-155        [2, 64, 32, 32]           --
# │    │    └─ReLU: 3-156                       [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-157                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-158        [2, 64, 32, 32]           --
# │    │    └─ReLU: 3-159                       [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-160                     [2, 64, 32, 32]           2,112
# │    └─DilatedResidualConv: 2-9               [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-161                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-162        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-163                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-164                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-165        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-166                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-167                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-10              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-168                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-169        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-170                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-171                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-172        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-173                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-174                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-11              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-175                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-176        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-177                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-178                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-179        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-180                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-181                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-12              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-182                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-183        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-184                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-185                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-186        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-187                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-188                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-13              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-189                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-190        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-191                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-192                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-193        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-194                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-195                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-14              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-196                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-197        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-198                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-199                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-200        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-201                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-202                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-15              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-203                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-204        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-205                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-206                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-207        [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-208                       [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-209                   [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2-16              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-210                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-211        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-212                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2-6               --                        (recursive)
# │    │    └─Conv2d: 3-213                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-214        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-215                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2-6               --                        (recursive)
# │    │    └─Identity: 3-216                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-17              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-217                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-218        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-219                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-220                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-221        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-222                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-223                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-18              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-224                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-225        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-226                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-227                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-228        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-229                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-230                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-19              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-231                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-232        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-233                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-234                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-235        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-236                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-237                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-20              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-238                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-239        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-240                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-241                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-242        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-243                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-244                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-21              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-245                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-246        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-247                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-248                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-249        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-250                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-251                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-22              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-252                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-253        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-254                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-255                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-256        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-257                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-258                   [2, 64, 32, 32]           --
# │    └─DilatedResidualConv: 2-23              [2, 64, 32, 32]           --
# │    │    └─Conv2d: 3-259                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-260        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-261                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-262                     [2, 64, 32, 32]           36,928
# │    │    └─LeadTimeConditioner: 3-263        [2, 64, 32, 32]           --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-264                       [2, 64, 32, 32]           --
# ├─ModuleList: 1-2                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-265                   [2, 64, 32, 32]           --
# ├─Upsample: 1-11                              [2, 64, 128, 128]         --
# ├─Conv2d: 1-12                                [2, 64, 128, 128]         4,160
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2-24              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-266                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-267        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-268                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2-7               --                        (recursive)
# │    │    └─Conv2d: 3-269                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-270        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-271                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2-7               --                        (recursive)
# │    │    └─Identity: 3-272                   [2, 64, 128, 128]         --
# │    └─DilatedResidualConv: 2-25              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-273                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-274        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-275                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-276                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-277        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-278                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-279                   [2, 64, 128, 128]         --
# │    └─DilatedResidualConv: 2-26              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-280                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-281        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-282                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-283                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-284        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-285                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-286                   [2, 64, 128, 128]         --
# │    └─DilatedResidualConv: 2-27              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-287                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-288        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-289                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-290                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-291        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-292                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-293                   [2, 64, 128, 128]         --
# │    └─DilatedResidualConv: 2-28              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-294                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-295        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-296                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-297                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-298        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-299                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-300                   [2, 64, 128, 128]         --
# │    └─DilatedResidualConv: 2-29              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-301                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-302        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-303                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-304                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-305        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-306                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-307                   [2, 64, 128, 128]         --
# │    └─DilatedResidualConv: 2-30              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-308                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-309        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-310                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-311                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-312        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-313                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-314                   [2, 64, 128, 128]         --
# │    └─DilatedResidualConv: 2-31              [2, 64, 128, 128]         --
# │    │    └─Conv2d: 3-315                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-316        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-317                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Conv2d: 3-318                     [2, 64, 128, 128]         36,928
# │    │    └─LeadTimeConditioner: 3-319        [2, 64, 128, 128]         --
# ├─ModuleList: 1-1                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─ReLU: 3-320                       [2, 64, 128, 128]         --
# ├─ModuleList: 1-3                             --                        --
# │    └─DilatedResidualConv: 2                 --                        --
# │    │    └─Identity: 3-321                   [2, 64, 128, 128]         --
# ├─Conv2d: 1-13                                [2, 1, 128, 128]          65
# ===============================================================================================
# Total params: 2,632,008
# Trainable params: 2,632,008
# Non-trainable params: 0
# Total mult-adds (G): 45.05
# ===============================================================================================
# Input size (MB): 4.72
# Forward/backward pass size (MB): 986.19
# Params size (MB): 10.53
# Estimated Total Size (MB): 1001.44
# ===============================================================================================

# %%
from metnet import MetNet

model = MetNet(
        hidden_dim=24,
        forecast_steps=24,
        input_channels=3,
        output_channels=1,
        sat_channels=1,
        input_size=128,
        )

x = torch.randn((4, 12, 3, 128, 128))

model(x, 0).shape
# Out:
# torch.Size([4, 1, 64, 64])

# %%
summary(model, (4, 12, 3, 128, 128))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# MetNet                                        --                        --
# ├─TemporalEncoder: 1                          --                        --
# │    └─ConvGRU: 2                             --                        --
# │    │    └─ModuleList: 3-1                   --                        57,120
# │    │    └─ModuleList: 3-2                   --                        --
# ├─Sequential: 1                               --                        --
# │    └─AxialAttention: 2                      --                        --
# │    │    └─ModuleList: 3-3                   --                        4,656
# ├─DownSample: 1-1                             [4, 12, 3, 64, 64]        --
# │    └─Sequential: 2                          --                        --
# │    │    └─MaxPool2d: 3-4                    [4, 36, 64, 64]           --
# ├─ConditionTime: 1-2                          [4, 12, 27, 64, 64]       --
# ├─TimeDistributed: 1-3                        [4, 12, 64, 16, 16]       --
# │    └─DownSampler: 2-1                       [48, 64, 16, 16]          --
# ├─Dropout: 1-4                                [4, 12, 64, 16, 16]       --
# ├─TemporalEncoder: 1-5                        [4, 12, 24, 16, 16]       --
# │    └─ConvGRU: 2-2                           [4, 12, 24, 16, 16]       --
# │    │    └─RNNDropout: 3-5                   [4, 12, 64, 16, 16]       --
# ├─Sequential: 1-6                             [4, 24, 16, 16]           --
# │    └─AxialAttention: 2-3                    [4, 24, 16, 16]           --
# ├─Sequential: 1-7                             [4, 1, 64, 64]            --
# │    └─ConvTranspose2d: 2-4                   [4, 32, 32, 32]           6,944
# │    └─ConvTranspose2d: 2-5                   [4, 1, 64, 64]            289
# ===============================================================================================
# Total params: 248,401
# Trainable params: 248,401
# Non-trainable params: 0
# Total mult-adds (G): 14.13
# ===============================================================================================
# Input size (MB): 9.44
# Forward/backward pass size (MB): 381.03
# Params size (MB): 0.99
# Estimated Total Size (MB): 391.46
# ===============================================================================================

# %%
out = []

for lead_time in range(3):
    output = model(x, lead_time)
    output = torch.nn.ConvTranspose2d(1, 1, kernel_size=3, stride=2, padding=1, output_padding=1)(output)
    out.append(output)
out = torch.stack(out, dim=1)
out.shape
# Out:
# torch.Size([2, 3, 1, 63, 63])

# %%
out = torch.reshape(out, (2, 3, 64, 64, 1))
out
# Out:
# tensor([[[[[0.1498],
#            [0.1448],
#            [0.1703],
#            ...,
#            [0.1835],
#            [0.1599],
#            [0.1651]],
#
#           [[0.1548],
#            [0.1446],
#            [0.1713],
#            ...,
#            [0.1929],
#            [0.1623],
#            [0.1666]],
#
#           [[0.1420],
#            [0.1366],
#            [0.1646],
#            ...,
#            [0.1743],
#            [0.1501],
#            [0.1565]],
#
#           ...,
#
#           [[0.1492],
#            [0.1447],
#            [0.1682],
#            ...,
#            [0.1814],
#            [0.1565],
#            [0.1626]],
#
#           [[0.1533],
#            [0.1464],
#            [0.1692],
#            ...,
#            [0.1836],
#            [0.1561],
#            [0.1656]],
#
#           [[0.1351],
#            [0.1290],
#            [0.1548],
#            ...,
#            [0.1690],
#            [0.1440],
#            [0.1494]]],
#
#
#          [[[0.1679],
#            [0.1429],
#            [0.1956],
#            ...,
#            [0.1868],
#            [0.1615],
#            [0.1718]],
#
#           [[0.1592],
#            [0.1258],
#            [0.1862],
#            ...,
#            [0.1830],
#            [0.1523],
#            [0.1624]],
#
#           [[0.1571],
#            [0.1293],
#            [0.1858],
#            ...,
#            [0.1761],
#            [0.1506],
#            [0.1597]],
#
#           ...,
#
#           [[0.1687],
#            [0.1406],
#            [0.1913],
#            ...,
#            [0.1846],
#            [0.1574],
#            [0.1688]],
#
#           [[0.1640],
#            [0.1411],
#            [0.1874],
#            ...,
#            [0.1828],
#            [0.1590],
#            [0.1667]],
#
#           [[0.1571],
#            [0.1268],
#            [0.1868],
#            ...,
#            [0.1768],
#            [0.1589],
#            [0.1613]]],
#
#
#          [[[0.1487],
#            [0.1696],
#            [0.1952],
#            ...,
#            [0.1921],
#            [0.1705],
#            [0.1800]],
#
#           [[0.1327],
#            [0.1472],
#            [0.1795],
#            ...,
#            [0.1767],
#            [0.1598],
#            [0.1617]],
#
#           [[0.1346],
#            [0.1500],
#            [0.1815],
#            ...,
#            [0.1742],
#            [0.1548],
#            [0.1635]],
#
#           ...,
#
#           [[0.1354],
#            [0.1518],
#            [0.1714],
#            ...,
#            [0.1741],
#            [0.1572],
#            [0.1608]],
#
#           [[0.1368],
#            [0.1505],
#            [0.1793],
#            ...,
#            [0.1791],
#            [0.1547],
#            [0.1619]],
#
#           [[0.1312],
#            [0.1471],
#            [0.1776],
#            ...,
#            [0.1722],
#            [0.1560],
#            [0.1604]]]],
#
#
#
#         [[[[0.1630],
#            [0.1666],
#            [0.1604],
#            ...,
#            [0.1725],
#            [0.1684],
#            [0.1640]],
#
#           [[0.1549],
#            [0.1627],
#            [0.1515],
#            ...,
#            [0.1632],
#            [0.1592],
#            [0.1585]],
#
#           [[0.1491],
#            [0.1548],
#            [0.1482],
#            ...,
#            [0.1601],
#            [0.1514],
#            [0.1520]],
#
#           ...,
#
#           [[0.1587],
#            [0.1615],
#            [0.1449],
#            ...,
#            [0.1695],
#            [0.1560],
#            [0.1588]],
#
#           [[0.1588],
#            [0.1619],
#            [0.1528],
#            ...,
#            [0.1640],
#            [0.1639],
#            [0.1571]],
#
#           [[0.1523],
#            [0.1581],
#            [0.1461],
#            ...,
#            [0.1585],
#            [0.1562],
#            [0.1540]]],
#
#
#          [[[0.1676],
#            [0.1560],
#            [0.1736],
#            ...,
#            [0.1667],
#            [0.1628],
#            [0.1688]],
#
#           [[0.1619],
#            [0.1515],
#            [0.1629],
#            ...,
#            [0.1568],
#            [0.1587],
#            [0.1637]],
#
#           [[0.1699],
#            [0.1525],
#            [0.1723],
#            ...,
#            [0.1638],
#            [0.1603],
#            [0.1660]],
#
#           ...,
#
#           [[0.1597],
#            [0.1495],
#            [0.1580],
#            ...,
#            [0.1635],
#            [0.1517],
#            [0.1645]],
#
#           [[0.1660],
#            [0.1547],
#            [0.1680],
#            ...,
#            [0.1697],
#            [0.1583],
#            [0.1643]],
#
#           [[0.1635],
#            [0.1514],
#            [0.1629],
#            ...,
#            [0.1599],
#            [0.1556],
#            [0.1623]]],
#
#
#          [[[0.1658],
#            [0.1879],
#            [0.1711],
#            ...,
#            [0.1812],
#            [0.1637],
#            [0.1515]],
#
#           [[0.1439],
#            [0.1634],
#            [0.1472],
#            ...,
#            [0.1570],
#            [0.1446],
#            [0.1324]],
#
#           [[0.1416],
#            [0.1604],
#            [0.1461],
#            ...,
#            [0.1554],
#            [0.1374],
#            [0.1297]],
#
#           ...,
#
#           [[0.1604],
#            [0.1741],
#            [0.1580],
#            ...,
#            [0.1785],
#            [0.1517],
#            [0.1440]],
#
#           [[0.1585],
#            [0.1798],
#            [0.1606],
#            ...,
#            [0.1717],
#            [0.1560],
#            [0.1414]],
#
#           [[0.1527],
#            [0.1710],
#            [0.1525],
#            ...,
#            [0.1630],
#            [0.1449],
#            [0.1366]]]]], grad_fn=<ReshapeAliasBackward0>)

# %%
torch.min(out)
# Out:
# tensor(0.0999, grad_fn=<MinBackward1>)

# %%
a = torch.randn((2, 1, 16, 16))
a.shape
# Out:
# torch.Size([2, 1, 16, 16])

# %%
torch.nn.ConvTranspose2d(1, 1, kernel_size=3, stride=2, padding=1, output_padding=1)(a)
# Out:
# False

# %%
import numpy as np

a1 = np.arange(128*128).reshape(128, 128)
a2 = np.arange(128*128).reshape(128, 128)
a = np.stack([a1, a2])
a = np.expand_dims(a, 0)  # (1, 2, _, _)
b = np.repeat(a, repeats=12, axis=0)
b.shape
# Out:
# (12, 2, 128, 128)

# %%
c = np.ones((12, 1, 128, 128))

# %%
np.concatenate([c, b], axis=1).shape
# Out:
# (12, 3, 128, 128)
